# %% [markdown]
# <a href="https://colab.research.google.com/github/carolina251280/Pr-ctica-Python/blob/main/Clase_4_Unidad_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import datetime

# %%
print("Fecha y hora actual:",datetime.datetime.now())
print("Año:", datetime.datetime.now().year)
print("Mes:", datetime.datetime.now().month)
print("Día:", datetime.datetime.now().day)
print("Día de la semana:", datetime.datetime.now().weekday())
# Out:
# Fecha y hora actual: 2025-08-24 02:34:24.755129
# Año: 2025
# Mes: 8
# Día: 24
# Día de la semana: 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time

# %%
print("Hora actual:", time.strftime("%H:%M:%S"))
print('Esperando 3 segundos...')
time.sleep(3)
print("¡Tiempo finalizado!")
# Out:
# Hora actual: 02:56:58
# Esperando 3 segundos...
# ¡Tiempo finalizado!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random as rd

# %%
numero1= rd.randrange(1,10)
numero2= rd.randrange(11,20)
numero3= rd.randrange(21,30)
numero4= rd.randrange(31,40)
numero5= rd.randrange(41,50)

# %%
print("Número 1:", numero1)
print("Número 2:", numero2)
print("Número 3:", numero3)
print("Número 4:", numero4)
print("Número 5:", numero5)
# Out:
# Número 1: 4
# Número 2: 18
# Número 3: 29
# Número 4: 39
# Número 5: 41

# %%
suma = numero1 + numero2 + numero3 + numero4 + numero5
print("La suma de los números generados es:", suma)
# Out:
# La suma de los números generados es: 131

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import datetime

# %%
ahora = datetime.datetime.now()
print("Fecha actual:", ahora)
# Out:
# Fecha actual: 2025-08-24 03:07:58.501874

# %%
fecha = datetime.datetime(1995,8,8)
print("Fecha de nacimiento:", fecha)
# Out:
# Fecha de nacimiento: 1995-08-08 00:00:00

# %%
diferencia = ahora - fecha
print("Diferencia:", diferencia)
# Out:
# Diferencia: 10974 days, 3:07:58.501874

# %%
diferenciaEnDias = diferencia.days
print("Diferencia en días:", diferenciaEnDias)
# Out:
# Diferencia en días: 10974

# %%
anios = diferenciaEnDias // 365
print("Tengo", anios, "años")
# Out:
# Tengo 30 años
